# %% [markdown]
# # 01 — Recolección de Datos Financieros
#
# **Objetivo:** descargar el histórico OHLCV completo (2005–2025) del universo S&P 500 más los índices de referencia (`^GSPC`, `^VIX`), y persistirlo en formato Parquet junto con metadata de reproducibilidad para alimentar las fases posteriores del pipeline.
#
# ---
#
# ### Pipeline del notebook
#
# 1. Configuración del entorno y rutas.
# 2. Declaración explícita de la limitación por sesgo de supervivencia.
# 3. Obtención de la lista de tickers desde Wikipedia.
# 4. Descarga vectorizada con `yfinance` (multithreading + reparación de datos).
# 5. Persistencia en Parquet + metadata JSON.
# 6. Verificación del dataset descargado.
#
# ### Salidas generadas
#
# - `data/massive_financial_data.parquet` — Dataset OHLCV con MultiIndex (Ticker × Métrica).
# - `data/data_collection_metadata.json` — Metadata de la descarga (timestamp, tickers fallidos, versiones de librerías).
#
# ### Dependencias
#
# ```
# pandas, numpy, yfinance, requests, pyarrow
# ```

# %% [markdown]
# ## 1. Configuración del entorno
#
# Definimos rutas, rangos temporales y constantes globales.
#
# **Estructura de directorios asumida:**
#
# ```
# bachelor-thesis/
# ├── notebooks/        ← este notebook
# └── data/             ← outputs (parquet + metadata)
# ```
#
# La constante `FORCE_DOWNLOAD` permite reutilizar la descarga almacenada en disco en ejecuciones sucesivas, evitando golpear innecesariamente la API de Yahoo Finance. Esto es especialmente útil cuando se itera sobre el feature engineering (notebook 02) sin necesidad de redescargar 500+ tickers cada vez.

# %%
import json
import logging
from datetime import datetime, timezone
from io import StringIO
from pathlib import Path

import pyarrow
import pandas as pd
import requests
import yfinance as yf

# Configuración de logging (mejor que prints sueltos: timestamps, niveles, formato)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)-8s | %(message)s",
    datefmt="%H:%M:%S",
)
logger = logging.getLogger("data_collection")

# %%
# --- Rango temporal ---
START_DATE = "2005-01-01"
END_DATE   = "2025-12-31"

# --- Control de re-descarga ---
# False: si el archivo ya existe, se carga de disco (rápido).
# True : fuerza descarga aunque exista (uso esporádico para refrescar datos).
FORCE_DOWNLOAD = False

# --- Rutas ---
# Se asume que el notebook se ejecuta desde un subdirectorio del proyecto
# (típicamente notebooks/) y los datos se almacenan en ../data/
BASE_DIR = Path.cwd().parent
DATA_DIR = BASE_DIR / "data"
DATA_DIR.mkdir(parents=True, exist_ok=True)

OUTPUT_FILE_PATH   = DATA_DIR / "massive_financial_data.parquet"
METADATA_FILE_PATH = DATA_DIR / "data_collection_metadata.json"

# --- Fuente de tickers ---
WIKI_URL = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

logger.info(f"BASE_DIR     : {BASE_DIR}")
logger.info(f"OUTPUT_FILE  : {OUTPUT_FILE_PATH}")
logger.info(f"METADATA_FILE: {METADATA_FILE_PATH}")
# Out:
# 11:42:11 | INFO     | BASE_DIR     : c:\Users\Usuario\Desktop\bachelor-thesis
# 11:42:11 | INFO     | OUTPUT_FILE  : c:\Users\Usuario\Desktop\bachelor-thesis\data\massive_financial_data.parquet
# 11:42:11 | INFO     | METADATA_FILE: c:\Users\Usuario\Desktop\bachelor-thesis\data\data_collection_metadata.json

# %% [markdown]
# ## 2. Limitación metodológica reconocida: sesgo de supervivencia
#
# La lista de tickers se obtiene de la composición **actual** del S&P 500 (Wikipedia). Esto introduce un **sesgo de supervivencia** (*survivorship bias*) en el dataset: el universo solo contiene empresas que han sobrevivido y permanecen en el índice a fecha de la descarga, excluyendo de forma sistemática:
#
# - Empresas quebradas o deslistadas (ej. *Lehman Brothers* en 2008, *Enron* en 2001).
# - Empresas absorbidas o fusionadas (ej. *Time Warner*, *Monsanto*).
# - Empresas expulsadas del índice por capitalización insuficiente o bajo desempeño.
#
# ### Implicaciones para el modelo
#
# - Los retornos históricos agregados del universo estarán **sesgados al alza**.
# - Las métricas obtenidas en backtest serán optimistas y no se replicarán fielmente en producción.
# - Factores como momentum o reversión a la media pueden mostrar señales artificialmente fuertes.
#
# ### Decisión metodológica adoptada en este TFG
#
# Se asume esta limitación de forma **explícita y declarada**. Mitigarla requeriría acceso a la composición histórica del índice (CRSP, Norgate Data, iShares historical holdings), datasets que están fuera del alcance computacional y de licencia de este trabajo. Las conclusiones del modelo se interpretarán siempre dentro de este contexto, y se discutirán en la sección de limitaciones de la memoria.

# %% [markdown]
# ## 3. Obtención del universo de activos
#
# Extraemos los tickers de la tabla principal del artículo *List of S&P 500 companies* en Wikipedia. Yahoo Finance emplea guiones en lugar de puntos para identificar clases de acciones (`BRK.B` → `BRK-B`, `BF.B` → `BF-B`), por lo que aplicamos la sustitución correspondiente.
#
# > **Nota de implementación:** envolvemos `response.text` en `StringIO` para evitar el `FutureWarning` que `pd.read_html` emite cuando recibe HTML literal directamente.

# %%
def get_sp500_tickers() -> list[str]:
    """
    Obtiene la composición ACTUAL del S&P 500 desde Wikipedia.

    Esta función NO recupera la composición histórica del índice; las
    implicaciones de esta decisión están documentadas en la sección 2
    de este notebook (Limitación metodológica).

    Returns
    -------
    list[str]
        Lista de tickers en formato compatible con Yahoo Finance.
        Devuelve lista vacía si la petición falla.
    """
    try:
        response = requests.get(WIKI_URL, headers=HEADERS, timeout=15)
        response.raise_for_status()
        # StringIO evita el FutureWarning de pandas con HTML literal
        df = pd.read_html(StringIO(response.text))[0]
        # Normalizamos la nomenclatura al formato de Yahoo Finance
        tickers = [t.replace(".", "-") for t in df["Symbol"].tolist()]
        logger.info(f"Obtenidos {len(tickers)} tickers del S&P 500 (Wikipedia).")
        return tickers
    except Exception as e:
        logger.error(f"Fallo al obtener la lista de tickers: {e}")
        return []

# %% [markdown]
# ## 4. Descarga del histórico OHLCV
#
# La descarga se realiza con `yfinance.download()` configurado con los siguientes parámetros:
#
# | Parámetro     | Valor      | Justificación |
# |---------------|------------|---------------|
# | `auto_adjust` | `True`     | Ajusta OHLC por *splits* y dividendos. Imprescindible para que la volatilidad Garman-Klass del notebook 02 sea consistente. |
# | `group_by`    | `"ticker"` | MultiIndex (Ticker × Métrica) facilita la extracción vectorizada con `.xs()`. |
# | `threads`     | `True`     | Multithreading para acelerar la descarga de >500 tickers. |
# | `repair`      | `True`     | Repara automáticamente errores menores en datos de Yahoo Finance (precios "raros", *splits* mal aplicados, etc.). |
#
# ### Estrategia de caché en disco
#
# Antes de iniciar la descarga, se verifica si el dataset ya existe en disco. Esto permite ejecutar el notebook completo sin redescargar datos, ahorrando tiempo y respetando los rate limits de Yahoo Finance. Para forzar una nueva descarga basta con `FORCE_DOWNLOAD = True`.
#
# ### Persistencia en formato Parquet
#
# Migramos de CSV a **Parquet** por tres razones técnicas relevantes para el TFG:
#
# 1. **Eficiencia de almacenamiento:** compresión columnar (~3–5× menor que CSV).
# 2. **Velocidad de E/S:** lectura ~5–10× más rápida.
# 3. **Preservación de tipos y MultiIndex:** el CSV serializa el MultiIndex como cabeceras de texto, lo que provoca el `DtypeWarning` al recargar y obliga a parsear manualmente. Parquet lo preserva nativamente.
#
# ### Metadata de reproducibilidad
#
# Junto al dataset se persiste un fichero JSON con: timestamp UTC de descarga, rango temporal, tickers exitosos, tickers fallidos y versiones de las librerías clave. Esto garantiza la trazabilidad completa de los resultados que aparecerán en la memoria.

# %%
def save_metadata(
    path: Path,
    start: str,
    end: str,
    requested: list[str],
    successful: list[str],
    failed: list[str],
) -> None:
    """
    Persiste metadata de la descarga en formato JSON para reproducibilidad.

    Parameters
    ----------
    path : Path
        Ruta de salida del fichero JSON.
    start, end : str
        Rango temporal de la descarga (formato YYYY-MM-DD).
    requested : list[str]
        Tickers solicitados a yfinance.
    successful : list[str]
        Tickers descargados con datos válidos.
    failed : list[str]
        Tickers que no devolvieron datos o devolvieron solo NaNs.
    """
    metadata = {
        "download_timestamp_utc": datetime.now(timezone.utc).isoformat(),
        "date_range": {"start": start, "end": end},
        "tickers": {
            "requested_count":  len(requested),
            "successful_count": len(successful),
            "failed_count":     len(failed),
            "requested":  requested,
            "successful": successful,
            "failed":     failed,
        },
        "library_versions": {
            "yfinance": yf.__version__,
            "pandas":   pd.__version__,
        },
    }
    with open(path, "w", encoding="utf-8") as f:
        json.dump(metadata, f, indent=2, ensure_ascii=False)
    logger.info(f"Metadata guardada en: {path}")

# %%
def download_massive_data(
    tickers: list[str],
    start: str,
    end: str,
    output_path: Path,
    metadata_path: Path,
    force: bool = False,
) -> pd.DataFrame | None:
    """
    Descarga el dataset OHLCV completo y lo persiste en formato Parquet.

    Parameters
    ----------
    tickers : list[str]
        Universo de activos a descargar.
    start, end : str
        Rango temporal (formato YYYY-MM-DD).
    output_path : Path
        Ruta del fichero Parquet de salida.
    metadata_path : Path
        Ruta del fichero JSON de metadata.
    force : bool
        Si False, no se redescarga cuando el archivo ya existe.

    Returns
    -------
    pd.DataFrame | None
        DataFrame con MultiIndex (Ticker × Métrica) en columnas.
        None si la descarga falla.
    """
    # 1. Caché de disco: evitar redescargas innecesarias
    if output_path.exists() and not force:
        logger.info(f"Archivo existente detectado en {output_path}.")
        logger.info("Cargando de disco. Para forzar nueva descarga: FORCE_DOWNLOAD=True.")
        return pd.read_parquet(output_path)

    # 2. Aseguramos el benchmark para el cálculo de Alpha/Beta posterior
    benchmark = "^GSPC"
    tickers_to_download = sorted(set(tickers) | {benchmark})

    logger.info(
        f"Iniciando descarga de {len(tickers_to_download)} tickers "
        f"({start} → {end})."
    )

    # 3. Descarga vectorizada
    data = yf.download(
        tickers_to_download,
        start=start,
        end=end,
        auto_adjust=True,    # OHLC ajustado por splits/dividendos
        group_by="ticker",   # MultiIndex (Ticker, Métrica)
        threads=True,        # Multithreading
        repair=True,         # Repara errores menores de Yahoo
        progress=True,
    )

    if data.empty:
        logger.error("La descarga no devolvió datos.")
        return None

    # 4. Detección de tickers fallidos (todo NaN o ausentes)
    detected_tickers = set(data.columns.get_level_values(0).unique())
    empty_tickers = {
        t for t in detected_tickers
        if data[t].isna().all().all()
    }
    failed_tickers = sorted(
        (set(tickers_to_download) - detected_tickers) | empty_tickers
    )

    # 5. Limpieza: eliminar columnas 100% vacías
    data = data.dropna(axis=1, how="all")

    # 5b. Eliminar la columna 'Repaired?' que añade yfinance con repair=True.
    #     Es metadata interna (qué precios ha reparado) con dtype 'object',
    #     que provoca ArrowKeyError al serializar a Parquet. No la usamos
    #     en el feature engineering posterior.
    if "Repaired?" in data.columns.get_level_values(1):
        data = data.drop(columns="Repaired?", level=1)
        logger.info("Columna 'Repaired?' eliminada (metadata de yfinance no usada).")

    # 5c. Forzar dtypes numéricos limpios. yfinance puede devolver columnas
    #     OHLCV como object si hay NaNs mezclados con valores reparados;
    #     pyarrow exige tipos homogéneos para serializar.
    data = data.astype("float64")

    successful_tickers = sorted(set(data.columns.get_level_values(0).unique()))

    logger.info(
        f"Resultado: {len(successful_tickers)} tickers exitosos, "
        f"{len(failed_tickers)} fallidos."
    )
    if failed_tickers:
        logger.warning(f"Tickers fallidos: {failed_tickers}")

    # 6. Persistencia en Parquet (preserva MultiIndex y dtypes)
    output_path.parent.mkdir(parents=True, exist_ok=True)
    try:
        data.to_parquet(output_path, engine="pyarrow", compression="snappy")
    except Exception as e:
        # Si la escritura falla, eliminamos el fichero parcial para evitar
        # que la siguiente ejecución cargue datos corruptos desde el caché.
        if output_path.exists():
            output_path.unlink()
        logger.error(f"Fallo al escribir Parquet: {e}")
        raise
    logger.info(f"Dataset guardado en: {output_path}")

    # 7. Metadata de reproducibilidad
    save_metadata(
        path=metadata_path,
        start=start,
        end=end,
        requested=tickers_to_download,
        successful=successful_tickers,
        failed=failed_tickers,
    )

    return data

# %% [markdown]
# ## 5. Ejecución del pipeline
#
# Componemos el universo final añadiendo los siguientes índices de mercado:
#
# - **`^GSPC`** — Índice S&P 500. Necesario como **benchmark** para calcular Beta y Volatilidad Idiosincrática en el notebook 02.
# - **`^VIX`** — Índice de volatilidad implícita (CBOE). Reservado como feature de **régimen de volatilidad** para incorporación posterior en el feature engineering. Captura el "miedo de mercado" y permite condicionar las señales según el contexto macro.

# %%
# Composición del universo
SP500_TICKERS   = get_sp500_tickers()
MARKET_INDICES  = ["^GSPC", "^VIX"]
ALL_TICKERS     = sorted(set(SP500_TICKERS) | set(MARKET_INDICES))

logger.info(f"Universo total a descargar: {len(ALL_TICKERS)} activos.")

# Ejecución
data = download_massive_data(
    tickers=ALL_TICKERS,
    start=START_DATE,
    end=END_DATE,
    output_path=OUTPUT_FILE_PATH,
    metadata_path=METADATA_FILE_PATH,
    force=FORCE_DOWNLOAD,
)
# Out:
# 11:42:11 | INFO     | Obtenidos 503 tickers del S&P 500 (Wikipedia).
# 11:42:11 | INFO     | Universo total a descargar: 505 activos.
# 11:42:11 | INFO     | Iniciando descarga de 505 tickers (2005-01-01 → 2025-12-31).
# [                       1%                       ]  6 of 505 completed11:42:15 | INFO     | DHR: 1d: price-repair-split: Corrected: 2005-01-03 -> 2016-07-01
# [***                    6%                       ]  28 of 505 completed11:42:17 | INFO     | TT: 1d: price-repair-split: Corrected: 2005-01-03 -> 2011-09-29
# [***                    7%                       ]  36 of 505 completed11:42:18 | INFO     | ^GSPC: 1d: price-reconstruct: Too old (1 rows tagged)
# [*******               14%                       ]  72 of 505 completed11:42:24 | INFO     | AMCR: 1d: div-adjust-repair-bad: Repaired missing div-adjust: ['2017-09-01']
# ...

# %% [markdown]
# ## 6. Verificación del dataset
#
# Comprobación final de las dimensiones, métricas disponibles y rango temporal del dataset descargado, antes de pasar al notebook `02-feature-engineering.ipynb`.

# %%
if data is not None:
    n_tickers = data.columns.get_level_values(0).nunique()
    metricas  = sorted(data.columns.get_level_values(1).unique().tolist())
    mem_mb    = data.memory_usage(deep=True).sum() / 1024**2

    print(f"Forma del DataFrame    : {data.shape}")
    print(f"Tickers únicos         : {n_tickers}")
    print(f"Métricas por ticker    : {metricas}")
    print(f"Rango temporal         : {data.index.min().date()} → {data.index.max().date()}")
    print(f"Memoria en RAM         : {mem_mb:.2f} MB")
    print(f"Benchmark ^GSPC presente: {'^GSPC' in data.columns.get_level_values(0)}")
    print(f"VIX ^VIX presente       : {'^VIX'  in data.columns.get_level_values(0)}")
else:
    print("La descarga no se completó correctamente. Revisar los logs anteriores.")
# Out:
# Forma del DataFrame    : (5295, 2525)
# Tickers únicos         : 505
# Métricas por ticker    : ['Close', 'High', 'Low', 'Open', 'Volume']
# Rango temporal         : 2005-01-03 → 2025-12-30
# Memoria en RAM         : 102.04 MB
# Benchmark ^GSPC presente: True
# VIX ^VIX presente       : True
